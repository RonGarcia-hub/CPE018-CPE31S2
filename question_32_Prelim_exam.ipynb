# %% [markdown]
# <a href="https://colab.research.google.com/github/RonGarcia-hub/CPE018-CPE31S2/blob/main/question_32_Prelim_exam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Write a Python script using OpenCV that:
#
#     Load and preprocess the image
#     Detect circles using Hough Circle Transform
#     Draw detected circles in red color
#     Save the result as circles_detected.png

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/circles.png')

channel = image[:, :, 0]

blur = cv2.GaussianBlur(channel, (9, 9), 1.5)

circles = cv2.HoughCircles(
    blur,
    cv2.HOUGH_GRADIENT,
    dp=1,
    minDist=150,
    param1=120,
    param2=45,
    minRadius=10,
    maxRadius=0
)

if circles is not None:
    circles = np.uint16(np.around(circles))
    for x, y, r in circles[0]:
        cv2.circle(image, (x, y), r, (0, 0, 255), 2)
        cv2.circle(image, (x, y), 2, (0, 0, 255), 3)
else:
    print("No circles detected.")

cv2_imshow(image)

cv2.imwrite('/content/circles_detected.png', image)
# Out:
# <PIL.Image.Image image mode=RGB size=720x540>
# True
